# %% [markdown]
# # Synthetic Data by Random Approach EDA

# %%
#Importing necessary libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Load the csv file
filename = "Synthetic_Data_Random_Approach.csv"
df = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/" + filename)
display(df)
# Out:
#               H2        CH4       C2H2       C2H4       C2H6  Fault
# 0       61449.90  231161.89  465178.24  424382.65   30151.27    NaN
# 1      223694.38   38909.94  365334.09  246798.98   91817.28    NaN
# 2       60747.06   95388.90  294200.10  353745.46   57556.64    NaN
# 3      119475.18  158234.71    1856.67  272050.76   59364.73    NaN
# 4      232677.57    5573.58   80037.07   22990.32  358807.32    NaN
# ...          ...        ...        ...        ...        ...    ...
# 99995  360582.57   26694.29  213105.03   11154.68  262988.38    NaN
# 99996  382512.02  331093.56  345193.75  329219.92  247462.74    NaN
# 99997  417313.98  412131.61  592999.93  182295.08  340260.05    NaN
# 99998  360147.60  387173.46  512212.96  256646.74  227064.60    NaN
# 99999  170189.69  348344.18   99206.25  103002.35  319237.28    NaN
#
# [100000 rows x 6 columns]

# %% [markdown]
# ### ***Correlation Determination***

# %%
corr_values =  df[["H2", "CH4", "C2H2", "C2H4", "C2H6"]].corr()

# %%
corr_values
# Out:
#             H2       CH4      C2H2      C2H4      C2H6
# H2    1.000000 -0.002029  0.001047  0.000182  0.002037
# CH4  -0.002029  1.000000 -0.003235 -0.004284  0.000876
# C2H2  0.001047 -0.003235  1.000000  0.001536 -0.001305
# C2H4  0.000182 -0.004284  0.001536  1.000000  0.002779
# C2H6  0.002037  0.000876 -0.001305  0.002779  1.000000

# %%
chart = sns.heatmap(corr_values, annot=True)
chart.set_title("Correlation between different dissolved gases")
plt.show()

# %% [markdown]
# The above heatmap shows the below observations:
# 1. There is a negative correltion between the values which shows that when some gases increses the other gases decrease which is not practically possible.
#
# Hence, this data cannot be considered as anywhere close to actual data.
